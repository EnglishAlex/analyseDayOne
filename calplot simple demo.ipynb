# %%
import numpy as np; np.random.seed(sum(map(ord, 'calplot')))
import pandas as pd
import calplot

all_days = pd.date_range('1/1/2019', periods=730, freq='D')
days = np.random.choice(all_days, 500)
events = pd.Series(np.random.randn(len(days)), index=days)
#We can use calplot() to plot all years as subplots into one figure:

# %%
events.head()

# %%
calplot.calplot(events, cmap='YlGn', colorbar=True)
# Out:
# (<Figure size 1250x340 with 3 Axes>,
#  array([<Axes: ylabel='2019'>, <Axes: ylabel='2020'>], dtype=object))

# %%
import numpy as np
import pandas as pd
import calplot

# Example existing series
data = {
    "2002-05-07": 1,
    "2008-11-05": 4,
    "2012-09-08": 2,
    "2013-02-24": 1,
    "2013-07-23": 1,
}
creationDate = pd.Series(list(data.values()), index=pd.to_datetime(list(data.keys())), name="count")

# Ensure the index is a DatetimeIndex
events = creationDate

# Print to verify
print(events)
# Out:
# 2002-05-07    1
# 2008-11-05    4
# 2012-09-08    2
# 2013-02-24    1
# 2013-07-23    1
# Name: count, dtype: int64
